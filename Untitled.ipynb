# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:


import pandas as pd

import pandas_profiling as pf


from matplotlib import pyplot as plt

import seaborn as sns

import numpy as np


# In[2]:


features=pd.read_csv("features.csv")

#features.shape

features.dtypes

#features[features.IsHoliday]


# In[3]:


#pf.ProfileReport(features)


# In[4]:


stores=pd.read_csv('stores.csv')

stores.head(45)


# In[5]:


import datetime as dt

train=pd.read_csv('train.csv')


train['col'] =pd.to_datetime (train.Date,format='%Y-%m-%d')

train['month']=train.col.dt.month

train['day']=train.col.dt.day

train['week']=train.col.dt.week


train['year']=train.col.dt.year



train.head(20)


# In[6]:


new_data=train.merge(features, on=['Store','Date'] ,how='left')







new_data=new_data.drop('IsHoliday_x',axis=1)

new_data=new_data.rename(columns={'IsHoliday_y':'IsHoliday'})


new_data=new_data.merge(stores,how='left', on='Store')

new_data.dtypes

#new_data.sort_values('Weekly_Sales')



#new_data=new_data.fillna(0)



new_data.describe().T


new_data.head()



# In[ ]:


data=pf.ProfileReport(new_data)
data.to_file('data.html')


# In[ ]:


new_data.columns


# In[ ]:


num=['Weekly_Sales','Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2',
       'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment','Size']

cat=['Store','Dept','month','day', 'week','year','IsHoliday', 'Type']

num_data=new_data[num]

cat_data=new_data[cat]

num_data.describe().T


# In[ ]:


num_data.corr()


# In[ ]:


def outliertreatment(x):
    x=x.clip(upper=x.quantile(0.99))
    x=x.clip(lower=x.quantile(0.01))
    return x


# In[ ]:


num_data=num_data.apply(outliertreatment)

num_data.describe().T


# In[ ]:


num_data.corr()


# In[ ]:


new_data.isna().sum()


# In[ ]:


sns.distplot((new_data.Weekly_Sales))

plt.show()


# In[ ]:


s=pd.read_csv('sampleSubmission.csv')

s.shape


# In[ ]:


test=pd.read_csv('test.csv')

test.shape


# In[ ]:


new_data.describe().T


# In[ ]:


sns.distplot(np.log(new_data.Weekly_Sales))

plt.show()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-d30e36a99369>", line 9, in <module>
#     import pandas_profiling as pf
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas_profiling\__init__.py", line 19, in <module>
#     from pandas_profiling.controller import pandas_decorator
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas_profiling\controller\pandas_decorator.py", line 3, in <module>
#     from pandas_profiling.__init__ import ProfileReport
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas_profiling\__init__.py", line 21, in <module>
#     from pandas_profiling.model.describe import describe as describe_df
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas_profiling\model\describe.py", line 25, in <module>
#     from pandas_profiling.view import plot
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas_profiling\view\plot.py", line 8, in <module>
#     import missingno
#   File "C:\ProgramData\Anaconda3\lib\site-packages\missingno\__init__.py", line 1, in <module>
#     from .missingno import matrix
#   File "C:\ProgramData\Anaconda3\lib\site-packages\missingno\missingno.py", line 6, in <module>
#     import seaborn as sns
#   File "C:\ProgramData\Anaconda3\lib\site-packages\seaborn\__init__.py", line 9, in <module>
#     from .relational import *
#   File "C:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py", line 18, in <module>
#     from .axisgrid import FacetGrid, _facet_docs
#   File "C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py", line 16, in <module>
#     from .distributions import distplot, kdeplot,  _freedman_diaconis_bins
#   File "C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py", line 16, in <module>
#     import statsmodels.nonparametric.api as smnp
#   File "C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\__init__.py", line 10, in <module>
#     from statsmodels.tools.sm_exceptions import (ConvergenceWarning, CacheWriteWarning,
#   File "C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tools\__init__.py", line 1, in <module>
#     from .tools import add_constant, categorical
#   File "C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tools\tools.py", line 11, in <module>
#     from statsmodels.datasets import webuse
#   File "C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\datasets\__init__.py", line 5, in <module>
#     from . import (anes96, cancer, committee, ccard, copper, cpunish, elnino,
#   File "C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\datasets\cancer\__init__.py", line 1, in <module>
#     from .data import *
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 963, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 906, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1280, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1252, in _get_spec
#   File "<frozen importlib._bootstrap_external>", line 1394, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 95, in _path_isfile
#   File "<frozen importlib._bootstrap_external>", line 87, in _path_is_mode_type
#   File "<frozen importlib._bootstrap_external>", line 81, in _path_stat
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2033, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\ultratb.py", line 347, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\ProgramData\Anaconda3\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\ProgramData\Anaconda3\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\ProgramData\Anaconda3\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\ProgramData\Anaconda3\lib\inspect.py", line 739, in getmodule
#     f = getabsfile(module)
#   File "C:\ProgramData\Anaconda3\lib\inspect.py", line 708, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "C:\ProgramData\Anaconda3\lib\inspect.py", line 693, in getsourcefile
#     if os.path.exists(filename):
#   File "C:\ProgramData\Anaconda3\lib\genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
